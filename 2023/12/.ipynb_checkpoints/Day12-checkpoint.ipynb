# %% [markdown]
# ### --- Day 12: Hot Springs ---
#
# You finally reach the hot springs! You can see steam rising from secluded areas attached to the primary, ornate building.
#
# As you turn to enter, the researcher stops you. "Wait - I thought you were looking for the hot springs, weren't you?" You indicate that this definitely looks like hot springs to you.
#
# "Oh, sorry, common mistake! This is actually the onsen! The hot springs are next door."
#
# You look in the direction the researcher is pointing and suddenly notice the massive metal helixes towering overhead. "This way!"
#
# It only takes you a few more steps to reach the main gate of the massive fenced-off area containing the springs. You go through the gate and into a small administrative building.
#
# "Hello! What brings you to the hot springs today? Sorry they're not very hot right now; we're having a lava shortage at the moment." You ask about the missing machine parts for Desert Island.
#
# "Oh, all of Gear Island is currently offline! Nothing is being manufactured at the moment, not until we get more lava to heat our forges. And our springs. The springs aren't very springy unless they're hot!"
#
# "Say, could you go up and see why the lava stopped flowing? The springs are too cold for normal operation, but we should be able to find one springy enough to launch you up there!"
#
# There's just one problem - many of the springs have fallen into disrepair, so they're not actually sure which springs would even be safe to use! Worse yet, their condition records of which springs are damaged (your puzzle input) are also damaged! You'll need to help them repair the damaged records.
#
# In the giant field just outside, the springs are arranged into rows. For each row, the condition records show every spring and whether it is operational (.) or damaged (#). This is the part of the condition records that is itself damaged; for some springs, it is simply unknown (?) whether the spring is operational or damaged.
#
# However, the engineer that produced the condition records also duplicated some of this information in a different format! After the list of springs for a given row, the size of each contiguous group of damaged springs is listed in the order those groups appear in the row. This list always accounts for every damaged spring, and each number is the entire size of its contiguous group (that is, groups are always separated by at least one operational spring: #### would always be 4, never 2,2).
#
# So, condition records with no unknown spring conditions might look like this:
# ```
# #.#.### 1,1,3
# .#...#....###. 1,1,3
# .#.###.#.###### 1,3,1,6
# ####.#...#... 4,1,1
# #....######..#####. 1,6,5
# .###.##....# 3,2,1
# ```
# However, the condition records are partially damaged; some of the springs' conditions are actually unknown (?). For example:
# ```
# ???.### 1,1,3
# .??..??...?##. 1,1,3
# ?#?#?#?#?#?#?#? 1,3,1,6
# ????.#...#... 4,1,1
# ????.######..#####. 1,6,5
# ?###???????? 3,2,1
# ```
# Equipped with this information, it is your job to figure out how many different arrangements of operational and broken springs fit the given criteria in each row.
#
# In the first line (???.### 1,1,3), there is exactly one way separate groups of one, one, and three broken springs (in that order) can appear in that row: the first three unknown springs must be broken, then operational, then broken (#.#), making the whole row #.#.###.
#
# The second line is more interesting: .??..??...?##. 1,1,3 could be a total of four different arrangements. The last ? must always be broken (to satisfy the final contiguous group of three broken springs), and each ?? must hide exactly one of the two broken springs. (Neither ?? could be both broken springs or they would form a single contiguous group of two; if that were true, the numbers afterward would have been 2,3 instead.) Since each ?? can either be #. or .#, there are four possible arrangements of springs.
#
# The last line is actually consistent with ten different arrangements! Because the first number is 3, the first and second ? must both be . (if either were #, the first number would have to be 4 or higher). However, the remaining run of unknown spring conditions have many different ways they could hold groups of two and one broken springs:
# ```
# ?###???????? 3,2,1
# .###.##.#...
# .###.##..#..
# .###.##...#.
# .###.##....#
# .###..##.#..
# .###..##..#.
# .###..##...#
# .###...##.#.
# .###...##..#
# .###....##.#
# ```
# In this example, the number of possible arrangements for each row is:
# ```
#     ???.### 1,1,3 - 1 arrangement
#     .??..??...?##. 1,1,3 - 4 arrangements
#     ?#?#?#?#?#?#?#? 1,3,1,6 - 1 arrangement
#     ????.#...#... 4,1,1 - 1 arrangement
#     ????.######..#####. 1,6,5 - 4 arrangements
#     ?###???????? 3,2,1 - 10 arrangements
# ```
# Adding all of the possible arrangement counts together produces a total of 21 arrangements.
#
# For each row, count all of the different arrangements of operational and broken springs that meet the given criteria. What is the sum of those counts?

# %%
# %%time
f = open("input.txt", "r")

def get_arrangement(spring):
    arrangement = []
    count = 0
    for i in range(len(spring)):
        if spring[i] == '.' and count != 0:
                arrangement.append(count)
                count = 0
        elif spring[i] == '#':
            count += 1
    
    if count != 0:
        arrangement.append(count)
    
    return arrangement

ways = 0
for line in f:
    line = line.replace('\n', '')
    
    spring = line[:line.find(" ")]
    arrangement = [int(number) for number in line[line.find(" ")+1:].split(',')]
    
    possible_springs = []
    unknowns = spring.count('?')
    
    index = -1
    while(unknowns):
        next_index = spring.find('?', index + 1)
        
        new_possible_springs = []
        
        if not possible_springs:
            new_possible_springs.append(spring[index + 1:next_index] + '.')
            new_possible_springs.append(spring[index + 1:next_index] + '#')
        else:
            for string in possible_springs:
                string += spring[index + 1:next_index]
                new_possible_springs.append(string + '.')
                new_possible_springs.append(string + '#')
        possible_springs = new_possible_springs
        index = next_index
        unknowns -= 1
    
    for possible_spring in possible_springs:
        possible_spring += spring[spring.rfind('?') + 1:]
        #print(possible_spring, get_arrangement(possible_spring), arrangement)
        if get_arrangement(possible_spring) == arrangement:
            ways += 1
    
ways
# Out:
# CPU times: total: 8.73 s
# Wall time: 20.1 s
# 7286

# %%
# %%time

# Improved part 1

f = open("input.txt", "r")

good_ways = []

ways = 0
for line in f:
    line = line.replace('\n', '')
    
    spring = line[:line.find(" ")]
    arrangement = [int(number) for number in line[line.find(" ")+1:].split(',')]

    good_ways.append(get_arrangements(arrangement, spring))
       
sum(good_ways)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 449 ms
# 7286

# %%
# %%time

# Improved part 1

f = open("input.txt", "r")

ways = 0
i = 0
for line in f:
    line = line.replace('\n', '')
    
    spring = line[:line.find(" ")]
    arrangement = [int(number) for number in line[line.find(" ")+1:].split(',')]
    
    way = get_arrangements_dac(arrangement, spring)
    if way != good_ways[i]:
        print(arrangement, spring, way, good_ways[i])
    
    ways += get_arrangements_dac(arrangement, spring)
    i += 1
       
ways
# Out:
# CPU times: total: 46.9 ms
# Wall time: 97 ms
# 7286

# %%
arrangements = {}

# %% [markdown]
# ### --- Part Two ---
#
# As you look out at the field of springs, you feel like there are way more springs than the condition records list. When you examine the records, you discover that they were actually folded up this whole time!
#
# To unfold the records, on each row, replace the list of spring conditions with five copies of itself (separated by ?) and replace the list of contiguous groups of damaged springs with five copies of itself (separated by ,).
#
# So, this row:
# ```
# .# 1
# ```
# Would become:
# ```
# .#?.#?.#?.#?.# 1,1,1,1,1
# ```
# The first line of the above example would become:
# ```
# ???.###????.###????.###????.###????.### 1,1,3,1,1,3,1,1,3,1,1,3,1,1,3
# ```
# In the above example, after unfolding, the number of possible arrangements for some rows is now much larger:
# ```
#     ???.### 1,1,3 - 1 arrangement
#     .??..??...?##. 1,1,3 - 16384 arrangements
#     ?#?#?#?#?#?#?#? 1,3,1,6 - 1 arrangement
#     ????.#...#... 4,1,1 - 16 arrangements
#     ????.######..#####. 1,6,5 - 2500 arrangements
#     ?###???????? 3,2,1 - 506250 arrangements
# ```
# After unfolding, adding all of the possible arrangement counts together produces 525152.
#
# Unfold your condition records; what is the new sum of possible arrangement counts?

# %%
arrangements = {}

def get_arrangements_all_unknowns(arrangement, length):
    key = "?"*length + " " + str(arrangement)
    if key in arrangements:
        return arrangements[key]
    
    if len(arrangement) == 0:
        return 1
    
    
    first_ways = length - arrangement[0] + 1
    if len(arrangement) == 1:
        return first_ways if first_ways > 0 else 0
    
    tail_length = sum(arrangement[1:]) + len(arrangement) - 1
    
    ways = 0
    for i in range(first_ways):
        remaining = length - arrangement[0] - i
        
        if remaining >= tail_length:
            ways += get_arrangements_all_unknowns(arrangement[1:], remaining - 1)
        else:
            break
    
    arrangements[key] = ways
    return ways

def get_arrangements(arrangement, spring):
    ways = 0
    
    index = spring.find('?')
    if index == -1: # Full spring
        ongoing = get_arrangement(spring)
        if len(ongoing) == len(arrangement):
            for i in range(len(ongoing)):
                if ongoing[i] != arrangement[i]:
                    return 0
            return 1
        else:
            return 0
    
    # Remove decided arrangements
    dot_index = spring[:index].rfind('.') # Leftmost . before a ?
    if dot_index != -1:
        decided_arrangement = get_arrangement(spring[ : dot_index])
        
        if len(decided_arrangement) > len(arrangement):
            return 0
        
        if len(decided_arrangement) > 0:
            for i in range(len(decided_arrangement)):
                if decided_arrangement[i] != arrangement[i]:
                    return 0
            
            spring = spring[dot_index + 1:]
            arrangement = arrangement[len(decided_arrangement):]
            index = spring.find('?')
    
    if spring.count('?') == len(spring) and len(arrangement) > 0:
        return get_arrangements_all_unknowns(arrangement, len(spring))
    
    # Explore
    for char in [".", "#"]:
        ways += get_arrangements(arrangement, spring.replace('?', char, 1))
        
    return ways

def get_arrangements_dac(arrangement, spring):
    ways = 0
    
    # TODO compress spring in key to remove duplicate dots
    key = spring + " " + str(arrangement)
    if key in arrangements:
        return arrangements[key]
    
    unknowns = spring.count('?')
    
    if unknowns == len(spring):
        return get_arrangements_all_unknowns(arrangement, unknowns)
    
    
    minimum_arrangement_length = sum(arrangement) + len(arrangement) - 1
    
    if minimum_arrangement_length == -1:
        if spring.count('#') > 0:
            return 0
        else:
            return 1
    
    # Try to find middle dot
    middle = spring.count('.') // 2 + 1
    index = spring.find('.')
    
    while(middle > 1):
        index = index + 1 + spring[index+1:].find('.')
        middle -= 1
    
    # Divide problem into subproblems
    if index != -1:
        left_length = index
        right_length = len(spring) - index - 1
        length = 0
        
        # Entire arrangement on right
        if right_length >= minimum_arrangement_length:
            ways += get_arrangements_dac(arrangement, spring[index + 1:])*get_arrangements_dac([], spring[:index])
        # Entire arrangement on left
        if left_length >= minimum_arrangement_length:
            ways += get_arrangements_dac(arrangement, spring[:index])*get_arrangements_dac([], spring[index + 1:])
        
        for i in range(len(arrangement)-1):
            length += arrangement[i]
            if i != 0 and i != len(arrangement) - 1:
                length += 1
                
            if left_length >= length and right_length >= minimum_arrangement_length - length - 1:
                ways += get_arrangements_dac(arrangement[:i+1], spring[:index])*get_arrangements_dac(arrangement[i+1:], spring[index + 1:])
    else: # No dot was found
        
        # Find sequences of #
        max_length_index = -1
        max_length = -1
        
        index = -1
        length = 0
        i = 0
        for char in spring:
            if char == "#":
                length += 1
                if length == 1:
                    index = i
            else:
                if length > max_length:
                    max_length = length
                    max_length_index = index
                length = 0
            i += 1
        
        if max_length > max(arrangement):
            return 0
        
        if max_length_index != -1 and max_length >= 2: # Found a sequence of #
            if max_length_index > 0:
                if spring[max_length_index - 1] == "?":
                    ways += get_arrangements_dac(arrangement, spring[:max_length_index - 1] + "." + spring[max_length_index:])
                    ways += get_arrangements_dac(arrangement, spring[:max_length_index - 1] + "#" + spring[max_length_index:])            
            elif max_length_index + max_length < len(spring):
                unknown = max_length_index + max_length
                if spring[unknown] == "?":
                    ways += get_arrangements_dac(arrangement, spring[:unknown] + "." + spring[unknown + 1:])
                    ways += get_arrangements_dac(arrangement, spring[:unknown] + "#" + spring[unknown + 1:])
        elif max_length == 1 and unknowns > 0:
            # Find middle ? and set it to both # and .
            # Try to find middle ?
            
            middle = unknowns // 2 + 1
            index = spring.find('?')

            while(middle > 1):
                index = index + 1 + spring[index+1:].find('?')
                middle -= 1
            ways += get_arrangements_dac(arrangement, spring[:index] + "." + spring[index + 1:])
            ways += get_arrangements_dac(arrangement, spring[:index] + "#" + spring[index + 1:])
        else:
            ways = get_arrangements(arrangement, spring) 
    arrangements[key] = ways
    return ways

# %%
len(arrangements)
# Out:
# 0

# %%
# %%time
f = open("input.txt", "r")
arrangements = {}
ways = 0
counter = 1
for line in f:
    line = line.replace('\n', '')
    
    spring = line[:line.find(" ")]
    arrangement = [int(number) for number in line[line.find(" ")+1:].split(',')]

    ways += get_arrangements_dac(arrangement*5, (spring + "?")*4 + spring)
ways
# Out:
# CPU times: total: 1.23 s
# Wall time: 2.91 s
# 25470469710341
